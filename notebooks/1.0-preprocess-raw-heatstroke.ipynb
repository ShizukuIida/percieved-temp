# %%
import os

import pandas as pd

# %%
cd_list = os.listdir('../data/raw/')
df_stroke = pd.read_csv(raw_data_path+cd_list[1])
df_stroke = df_stroke[12::47]
for data_name in cd_list[2:]:
    print(data_name)
    path = raw_data_path + data_name
    df_temp = pd.read_csv(path)
    
    df_temp = df_temp[12::47]
    df_stroke = pd.concat([df_stroke, df_temp], axis=0)
df_stroke.reset_index(inplace=True, drop=True)
# Out:
# heatstroke003_data_r4_07.csv
# heatstroke003_data_r4_08.csv
# heatstroke003_data_r4_09.csv

# %%
df_stroke
# Out:
#             日付  都道府県コード  搬送人員（計）  年齢区分：新生児  年齢区分：乳幼児  年齢区分：少年  年齢区分：成人  \
# 0     2022/6/1       13       18         0         0        6        0
# 1     2022/6/2       13       19         0         0        8        6
# 2     2022/6/3       13        3         0         0        1        2
# 3     2022/6/4       13       13         0         0        6        4
# 4     2022/6/5       13       11         0         0        3        5
# ..         ...      ...      ...       ...       ...      ...      ...
# 117  2022/9/26       13        7         0         0        0        3
# 118  2022/9/27       13        4         0         0        1        1
# 119  2022/9/28       13        1         0         0        0        0
# 120  2022/9/29       13        0         0         0        0        0
# 121  2022/9/30       13        5         0         0        2        2
#
#      年齢区分：高齢者  年齢区分：不明  傷病程度：死亡  ...  傷病程度：軽症  傷病程度：その他  発生場所：住居  発生場所：仕事場①  \
# ...

# %%
df_stroke['搬送人員（計）'].plot()
# Out:
# <AxesSubplot:>

# %%
processed_data_path = '../data/processed/'
df_stroke.to_csv(processed_data_path+'heat_stroke.csv', index=False)

# %%
pd.read_csv(processed_data_path+'heat_stroke.csv')
# Out:
#             日付  都道府県コード  搬送人員（計）  年齢区分：新生児  年齢区分：乳幼児  年齢区分：少年  年齢区分：成人  \
# 0     2022/6/1       13       18         0         0        6        0
# 1     2022/6/2       13       19         0         0        8        6
# 2     2022/6/3       13        3         0         0        1        2
# 3     2022/6/4       13       13         0         0        6        4
# 4     2022/6/5       13       11         0         0        3        5
# ..         ...      ...      ...       ...       ...      ...      ...
# 117  2022/9/26       13        7         0         0        0        3
# 118  2022/9/27       13        4         0         0        1        1
# 119  2022/9/28       13        1         0         0        0        0
# 120  2022/9/29       13        0         0         0        0        0
# 121  2022/9/30       13        5         0         0        2        2
#
#      年齢区分：高齢者  年齢区分：不明  傷病程度：死亡  ...  傷病程度：軽症  傷病程度：その他  発生場所：住居  発生場所：仕事場①  \
# ...
